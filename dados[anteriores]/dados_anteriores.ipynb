# %%
# @title bibliotecas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
color_pal = sns.color_palette("Paired", 10)

color_pal
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509)]

# %% [markdown]
# O dataset

# %%
df = pd.read_csv('dados/dataset/inventory.csv')

df
# Out:
#      Store        Date                                    Product  \
# 0        1  05-02-2010                   Blueberry scented candle
# 1        4  12-02-2010               Stainless steel water bottle
# 2        5  19-02-2010                      Leather messenger bag
# 3        2  26-02-2010                        Organic coconut oil
# 4        3  05-03-2010                 Bluetooth wireless earbuds
# ..     ...         ...                                        ...
# 494      5  06-05-2011               Yoga mat with carrying strap
# 495      2  13-05-2011  Stainless steel french press coffee maker
# 496      3  20-05-2011             Memory foam travel neck pillow
# 497      1  27-05-2011             Glass meal prep containers set
# 498      4  03-06-2011                       Vegan leather wallet
#
#      Weekly_Sales  inventory level  Temperature  \
# 0      1643690.90                0        42.31
# 1      1641957.44                1        38.51
# ...

# %%
product_q = df['Product'].value_counts()

product_q
# Out:
# Product
# Blueberry scented candle                     25
# Stainless steel water bottle                 25
# Leather messenger bag                        25
# Organic coconut oil                          25
# Bluetooth wireless earbuds                   25
# Floral patterned throw pillow                25
# Bamboo cutting board set                     25
# Aromatherapy essential oil diffuser          25
# Resistance band set                          25
# Ceramic plant pot with saucer                25
# Insulated lunch box                          25
# Himalayan salt lamp                          25
# Reusable silicone food storage bags          25
# Handwoven rattan basket                      25
# Yoga mat with carrying strap                 25
# Stainless steel french press coffee maker    25
# Memory foam travel neck pillow               25
# Glass meal prep containers set               25
# Vegan leather wallet                         25
# ...

# %%
product_str = df['Store'].value_counts()

product_str
# Out:
# Store
# 2    137
# 1     91
# 4     91
# 5     90
# 3     90
# Name: count, dtype: int64

# %%
colunas_out = ['demand forecast']

df_attz = df.drop(colunas_out, axis=1)

df_attz = df_attz[df_attz['Store'] == 2]

# %%
df_attz.reset_index(drop=True)

df_attz
# Out:
#      Store        Date                                    Product  \
# 3        2  26-02-2010                        Organic coconut oil
# 5        2  12-03-2010              Floral patterned throw pillow
# 9        2  09-04-2010              Ceramic plant pot with saucer
# 14       2  14-05-2010               Yoga mat with carrying strap
# 16       2  28-05-2010             Memory foam travel neck pillow
# ..     ...         ...                                        ...
# 480      2  28-01-2011                   Blueberry scented candle
# 484      2  25-02-2011                 Bluetooth wireless earbuds
# 489      2  01-04-2011              Ceramic plant pot with saucer
# 491      2  15-04-2011                        Himalayan salt lamp
# 495      2  13-05-2011  Stainless steel french press coffee maker
#
#      Weekly_Sales  inventory level  Temperature  \
# 3      1409727.59                0        46.63
# 5      1439541.59                0        57.79
# ...

# %%
df2 = pd.read_csv('dados2/tech-dataset.csv')

df2
# Out:
#         RegionName               CountryName        State       City  \
# 0    South America  United States of America        Texas  Southlake
# 1    South America  United States of America        Texas  Southlake
# 2    South America  United States of America        Texas  Southlake
# 3    South America  United States of America        Texas  Southlake
# 4    South America  United States of America        Texas  Southlake
# ..             ...                       ...          ...        ...
# 395           Asia                     India  Maharashtra     Bombay
# 396           Asia                     India  Maharashtra     Bombay
# 397           Asia                     India  Maharashtra     Bombay
# 398           Asia                     India  Maharashtra     Bombay
# 399           Asia                     India  Maharashtra     Bombay
#
#     PostalCode     WarehouseAddress    WarehouseName     EmployeeName  \
# ...

# %%
colunas_remover = ['PostalCode', 'WarehouseAddress', 'WarehouseName',
'EmployeeName', 'EmployeeEmail', 'EmployeePhone', 'EmployeeJobTitle', 'ProductDescription',
'CustomerCreditLimit', 'CustomerAddress', 'CustomerEmail', 'CustomerPhone']

# %%
df_att = df2.drop(colunas_remover, axis=1)

# %% [markdown]
# Entendendo o Dataset

# %%
df_att
# Out:
#         RegionName               CountryName        State       City  \
# 0    South America  United States of America        Texas  Southlake
# 1    South America  United States of America        Texas  Southlake
# 2    South America  United States of America        Texas  Southlake
# 3    South America  United States of America        Texas  Southlake
# 4    South America  United States of America        Texas  Southlake
# ..             ...                       ...          ...        ...
# 395           Asia                     India  Maharashtra     Bombay
# 396           Asia                     India  Maharashtra     Bombay
# 397           Asia                     India  Maharashtra     Bombay
# 398           Asia                     India  Maharashtra     Bombay
# 399           Asia                     India  Maharashtra     Bombay
#
#     EmployeeHireDate CategoryName                              ProductName  \
# ...

# %%
product_q = df_att['ProductName'].value_counts()
product_q[product_q > 4].index
# Out:
# Index(['G.Skill Ripjaws V Series', 'Corsair Dominator Platinum',
#        'G.Skill Trident Z', 'Corsair Vengeance LPX', 'Kingston'],
#       dtype='object', name='ProductName')

# %%
df_att.plot(style='o',
        figsize=(15, 5),
        color=color_pal,
        title='Inventario de produtos')
# Out:
# <Axes: title={'center': 'Inventario de produtos'}>

# %%
plt.plot(df_att['ProductName'], df_att['ProductStock'], 'o', color='black')
# Out:
# RangeIndex(start=0, stop=400, step=1)
